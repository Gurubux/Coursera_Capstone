# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Scrape, Wrangle and Clean the DataFrame
# https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Mumbai

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Gurubux/Coursera_Capstone/master/Final/Mumbai_neighbourhood.csv',sep='\t')
df.head()
# Out:
#               Town  ...                                      Neighbourhood
# 0  Western Suburbs  ...  Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...
# 1  Western Suburbs  ...  Bandra Kurla Complex,Bandstand Promenade,Gandh...
# 2  Western Suburbs  ...  I.C. Colony,L.I.C. Colony aka Jeevan Bhima Nag...
# 3  Western Suburbs  ...                   Magathane,Nancy Colony,Sukurwadi
# 4  Western Suburbs  ...                                            Dahisar
#
# [5 rows x 3 columns]

# %%
# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.6/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.6/dist-packages (from geopy) (1.49)

# %%
"""for index, row in df.iterrows():
  print(row['Station'])
  address = row['Station']+', Mumbai'
  geolocator = Nominatim(user_agent="foursquare_agent")
  if(geolocator.geocode(address) != None):
    print(address,'>>',geolocator.geocode(address).latitude, geolocator.geocode(address).longitude)
    df.set_value(index,'Latitude',geolocator.geocode(address).latitude)
    df.set_value(index,'Longitude',geolocator.geocode(address).longitude)
    """
# Out:
# 'for index, row in df.iterrows():\n  print(row[\'Station\'])\n  address = row[\'Station\']+\', Mumbai\'\n  geolocator = Nominatim(user_agent="foursquare_agent")\n  if(geolocator.geocode(address) != None):\n    print(address,\'>>\',geolocator.geocode(address).latitude, geolocator.geocode(address).longitude)\n    df.set_value(index,\'Latitude\',geolocator.geocode(address).latitude)\n    df.set_value(index,\'Longitude\',geolocator.geocode(address).longitude)\n    '

# %%
#df.set_value(21,'Latitude',18.949169)
#df.set_value(21,'Longitude',72.826828)

# %%
#df.to_csv('/content/sample_data/Mumbai_neighbourhood_Final.csv', header=True, index=False, encoding='utf-8')

# %%
df_mum = pd.read_csv('https://raw.githubusercontent.com/Gurubux/Coursera_Capstone/master/Final/Mumbai_neighbourhood_Final.csv',sep=',')
df_mum.head()
# Out:
#               Town        Station  ...   Latitude  Longitude
# 0  Western Suburbs        Andheri  ...  19.119698  72.846420
# 1  Western Suburbs         Bandra  ...  19.054979  72.840220
# 2  Western Suburbs       Borivali  ...  19.229068  72.857363
# 3  Western Suburbs  Borivali East  ...  19.226723  72.861933
# 4  Western Suburbs        Dahisar  ...  19.257178  72.857536
#
# [5 rows x 5 columns]

# %%
import folium # plotting library
address = 'Mumbai, India'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Mumbai City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Mumbai City are 18.9387711, 72.8353355.

# %%
# create map of New York using latitude and longitude values
map_mumbai = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_mum['Latitude'], df_mum['Longitude'], df_mum['Station'], df_mum['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [np.float(lat), np.float(lng)],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,parse_html=False).add_to(map_mumbai)  
    
map_mumbai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !pip install folium
import folium # plotting library
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.10.1)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.16.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)

# %%
CLIENT_ID = 'QSOKNRAASIUJLTFPCEXHCZD0K11LEPJ1NL05S4FG33XPLWBW' # your Foursquare ID 
CLIENT_SECRET = 'T550UGX5ZEOHGNRS3BV5D3BCJ4JFPTW40XBWREO12PDYM5GU' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QSOKNRAASIUJLTFPCEXHCZD0K11LEPJ1NL05S4FG33XPLWBW
# CLIENT_SECRET:T550UGX5ZEOHGNRS3BV5D3BCJ4JFPTW40XBWREO12PDYM5GU

# %%
print(df_mum.shape)
#df_mum.head(38)
# Out:
# (55, 5)

# %% [markdown]
# ## 2. Explore Neighbourhood Venues in
#
# Nariman Point,
#
# Malabar Hill,
#
# Breach Candy,
#
# Juhu,
#
# Hindu colony/Parsi Colony,
#
# Churchgate,
#
# Dahisar,
#
# Lower Parel,
#
# Sion,
#
# Ballard Estate

# %%
neighborhood_latitude = df_mum.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df_mum.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df_mum.loc[0, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Nagar,Lokhandwala,Marol,Model Town,Oshiwara,Poonam Nagar,Sahar,Saki Naka,Seven Bungalows,Versova are 19.119697600000002, 72.8464205.

# %%
# type your answer here
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 2000 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=QSOKNRAASIUJLTFPCEXHCZD0K11LEPJ1NL05S4FG33XPLWBW&client_secret=T550UGX5ZEOHGNRS3BV5D3BCJ4JFPTW40XBWREO12PDYM5GU&v=20180604&ll=19.119697600000002,72.8464205&radius=2000&limit=100'

# %%
import requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d6cb775d0a149002c342adf'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587e2f964a52095a522e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4b0587e2f964a52095a522e3',
#        'location': {'address': 'Near Andheri Station, SV Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Andheri West',
#         'distance': 114,
#         'formattedAddress': ['Near Andheri Station, SV Road (Andheri West)',
#          'Mumbai 400 058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.119300215885474,
#           'lng': 72.84541776016009}],
#         'lat': 19.119300215885474,
#         'lng': 72.84541776016009,
#         'postalCode': '400 058',
#         'state': 'Mahārāshtra'},
#        'name': 'Merwans Cake shop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4df9c1b3b3ad7391e9c7bf07-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '4df9c1b3b3ad7391e9c7bf07',
#        'location': {'address': 'Near Chinai College',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Nagardas Road',
#         'distance': 446,
#         'formattedAddress': ['Near Chinai College (Nagardas Road)',
#          'Mumbai 400069',
#          'Mahrashtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.121397691078766,
#           'lng': 72.85027035501028}],
#         'lat': 19.121397691078766,
#         'lng': 72.85027035501028,
#         'postalCode': '400069',
#         'state': 'Mahrashtra'},
#        'name': 'Narayan Sandwich',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ca5a6ead971b1f7d963f8e0-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4ca5a6ead971b1f7d963f8e0',
#        'location': {'address': 'Viral Apartment,Ground Floor, Road No. 50,',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'opp Shoppers Stop, SV Road, Andheri West,',
#         'distance': 619,
#         'formattedAddress': ['Viral Apartment,Ground Floor, Road No. 50, (opp Shoppers Stop, SV Road, Andheri West,)',
#          'Mumbai 400058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.115130144160013,
#           'lng': 72.84305962889206}],
#         'lat': 19.115130144160013,
#         'lng': 72.84305962889206,
#         'postalCode': '400058',
#         'state': 'Mahārāshtra'},
#        'name': 'Radha Krishna Veg Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b8e7350f964a520452333e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4b8e7350f964a520452333e3',
#        'location': {'address': 'Opp. Andheri Railway Station (West)',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Andheri',
#         'distance': 33,
#         'formattedAddress': ['Opp. Andheri Railway Station (West) (Andheri)',
#          'Mumbai 400058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.119691210789103,
#           'lng': 72.84610244862697}],
#         'lat': 19.119691210789103,
#         'lng': 72.84610244862697,
#         'postalCode': '400058',
#         'state': 'Mahārāshtra'},
#        'name': "McDonald's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5174e2be498e39cf0d1c20cb-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'primary': True,
#          'shortName': 'Falafel'}],
#        'id': '5174e2be498e39cf0d1c20cb',
#        'location': {'address': 'Dadabhai Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Off JP Road, Near Navrang Cinema',
#         'distance': 835,
#         'formattedAddress': ['Dadabhai Road (Off JP Road, Near Navrang Cinema)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.124590572173467,
#           'lng': 72.8403981304492}],
#         'lat': 19.124590572173467,
#         'lng': 72.8403981304492,
#         'state': 'Mahārāshtra'},
#        'name': 'Shawarma Factory',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5353bd55498ed44d14437bd3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '5353bd55498ed44d14437bd3',
#        'location': {'address': 'Next to ONGC',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'near irla',
#         'distance': 1350,
#         'formattedAddress': ['Next to ONGC (near irla)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.11120350275779,
#           'lng': 72.83725536561151}],
#         'lat': 19.11120350275779,
#         'lng': 72.83725536561151,
#         'state': 'Mahārāshtra'},
#        'name': 'Naturals',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d958f4fb188721ec43ce136-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4d958f4fb188721ec43ce136',
#        'location': {'address': 'Andheri Kurla Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1064,
#         'formattedAddress': ['Andheri Kurla Road',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.116154809545993,
#           'lng': 72.85581626501495}],
#         'lat': 19.116154809545993,
#         'lng': 72.85581626501495,
#         'state': 'Mahārāshtra'},
#        'name': 'Maharaja Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e6ded42d1647053b9ddd74c-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4e6ded42d1647053b9ddd74c',
#        'location': {'address': 'Irla',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'S V Road',
#         'distance': 849,
#         'formattedAddress': ['Irla (S V Road)',
#          'Mumbai 400058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.113767032154076,
#           'lng': 72.84133700180305}],
#         'lat': 19.113767032154076,
#         'lng': 72.84133700180305,
#         'postalCode': '400058',
#         'state': 'Mahārāshtra'},
#        'name': 'Temptations',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55a272a3498e529c48a29639-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '55a272a3498e529c48a29639',
#        'location': {'address': '4th Floor Tian Building',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Gulmohar Road, Juhu',
#         'distance': 1218,
#         'formattedAddress': ['4th Floor Tian Building (Gulmohar Road, Juhu)',
#          'Mumbai 400049',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.11453791935084,
#           'lng': 72.83620406918541}],
#         'lat': 19.11453791935084,
#         'lng': 72.83620406918541,
#         'postalCode': '400049',
#         'state': 'Mahārāshtra'},
#        'name': 'Quench- All Day Pub',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56c601e4cd106842405d39f4-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '56c601e4cd106842405d39f4',
#        'location': {'address': 'Tian',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Juhu lane',
#         'distance': 1216,
#         'formattedAddress': ['Tian (Juhu lane)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.114568642889374,
#           'lng': 72.83620488457646}],
#         'lat': 19.114568642889374,
#         'lng': 72.83620488457646,
#         'state': 'Mahārāshtra'},
#        'name': 'Starbucks Coffee : A Tata Alliance',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cc1d37c3d7fa1cd0de39a5f-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4cc1d37c3d7fa1cd0de39a5f',
#        'location': {'address': '6 & 7, Upvan Bldg, Behind Indian Oil Colony, D N Nagar, New Lic Colony Rd, Andheri (W)',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Andheri',
#         'distance': 1897,
#         'formattedAddress': ['6 & 7, Upvan Bldg, Behind Indian Oil Colony, D N Nagar, New Lic Colony Rd, Andheri (W) (Andheri)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.126762155150107,
#           'lng': 72.83000121236746}],
#         'lat': 19.126762155150107,
#         'lng': 72.83000121236746,
#         'state': 'Mahārāshtra'},
#        'name': "Joey's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d10d39b7177b1f7d2c75322-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4d10d39b7177b1f7d2c75322',
#        'location': {'address': 'S V Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Andheri West',
#         'distance': 1030,
#         'formattedAddress': ['S V Road (Andheri West)',
#          'Mumbai 400058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.12893009094341,
#           'lng': 72.84714004510111}],
#         'lat': 19.12893009094341,
#         'lng': 72.84714004510111,
#         'postalCode': '400058',
#         'state': 'Mahārāshtra'},
#        'name': 'Cafe Arfa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c8f5bd74e95236a6e1c83ca-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4c8f5bd74e95236a6e1c83ca',
#        'location': {'address': 'Juhu Supreme Shopping Centre',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'JVPD Scheme, Juhu',
#         'distance': 1345,
#         'formattedAddress': ['Juhu Supreme Shopping Centre (JVPD Scheme, Juhu)',
#          'Mumbai 400049',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.11530465003514,
#           'lng': 72.83450051026293}],
#         'lat': 19.11530465003514,
#         'lng': 72.83450051026293,
#         'postalCode': '400049',
#         'state': 'Mahārāshtra'},
#        'name': 'Tewari Bros Sweets',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53e897c4498e85fdd68f8fe4-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '53e897c4498e85fdd68f8fe4',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 1349,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.109424253865374,
#           'lng': 72.85322394388633}],
#         'lat': 19.109424253865374,
#         'lng': 72.85322394388633},
#        'name': 'Basil The Italian Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b812590f964a5205d9830e3-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'primary': True,
#          'shortName': 'Juice Bar'}],
#        'id': '4b812590f964a5205d9830e3',
#        'location': {'address': '1st Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Vile Parle (West)',
#         'distance': 1500,
#         'formattedAddress': ['1st Road (Vile Parle (West))',
#          'Mumbai 400056',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.109553332973178,
#           'lng': 72.83702080840025}],
#         'lat': 19.109553332973178,
#         'lng': 72.83702080840025,
#         'postalCode': '400056',
#         'state': 'Mahārāshtra'},
#        'name': 'Amar Juice Centre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b46128bf964a520751526e3-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4b46128bf964a520751526e3',
#        'location': {'address': 'Opp. Andheri Sports Complex, Andheri',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'JP Rd.',
#         'distance': 1256,
#         'formattedAddress': ['Opp. Andheri Sports Complex, Andheri (JP Rd.)',
#          'Mumbai 400058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.127188369589465,
#           'lng': 72.83747791351865}],
#         'lat': 19.127188369589465,
#         'lng': 72.83747791351865,
#         'postalCode': '400058',
#         'state': 'Mahārāshtra'},
#        'name': 'Garden Court',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52b3fe27498e991e4fe996cb-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '52b3fe27498e991e4fe996cb',
#        'location': {'address': 'Crystal Paradise',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Off Veera Desai, Andheri',
#         'distance': 1835,
#         'formattedAddress': ['Crystal Paradise (Off Veera Desai, Andheri)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.131893498780688,
#           'lng': 72.83466849836763}],
#         'lat': 19.131893498780688,
#         'lng': 72.83466849836763,
#         'state': 'Mahārāshtra'},
#        'name': 'Pizza Express',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cb74576589f236a45983d3d-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4cb74576589f236a45983d3d',
#        'location': {'address': 'S V Road, Irla',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Irla',
#         'distance': 1587,
#         'formattedAddress': ['S V Road, Irla (Irla)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.106768109172727,
#           'lng': 72.84005519074948}],
#         'lat': 19.106768109172727,
#         'lng': 72.84005519074948,
#         'state': 'Mahārāshtra'},
#        'name': 'Temptations',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e6cd1dc1495f34925b21012-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4e6cd1dc1495f34925b21012',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'vile parle west',
#         'distance': 2000,
#         'formattedAddress': ['vile parle west',
#          'Mumbai 400056',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.104219376484483,
#           'lng': 72.83675861374584}],
#         'lat': 19.104219376484483,
#         'lng': 72.83675861374584,
#         'postalCode': '400056',
#         'state': 'Mahārāshtra'},
#        'name': 'The Chocolate Heaven',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ccd2b97566aa093965f26fd-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'primary': True,
#          'shortName': 'Seafood'}],
#        'id': '4ccd2b97566aa093965f26fd',
#        'location': {'address': 'Irla',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Juhu',
#         'distance': 1397,
#         'formattedAddress': ['Irla (Juhu)', 'Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.10851908963802,
#           'lng': 72.8403827444371}],
#         'lat': 19.10851908963802,
#         'lng': 72.8403827444371,
#         'state': 'Mahārāshtra'},
#        'name': 'Harish: Restaurant & Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e7eceec00391d78f8e2b696-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'primary': True,
#          'shortName': 'Snacks'}],
#        'id': '4e7eceec00391d78f8e2b696',
#        'location': {'address': 'Hanuman Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Vile Parle East',
#         'distance': 1837,
#         'formattedAddress': ['Hanuman Road (Vile Parle East)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.1033126238013,
#           'lng': 72.84857615037404}],
#         'lat': 19.1033126238013,
#         'lng': 72.84857615037404,
#         'state': 'Mahārāshtra'},
#        'name': 'Babu Cha Vada',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51fb7853498e2d2b68bc9b7c-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '51fb7853498e2d2b68bc9b7c',
#        'location': {'address': 'Koteshwar Palace, Shop No 2',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Jumbo Darshan',
#         'distance': 1219,
#         'formattedAddress': ['Koteshwar Palace, Shop No 2 (Jumbo Darshan)',
#          'Mumbai 400069',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.11065238563932,
#           'lng': 72.85296431874953}],
#         'lat': 19.11065238563932,
#         'lng': 72.85296431874953,
#         'postalCode': '400069',
#         'state': 'Mahārāshtra'},
#        'name': 'King chilly',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfc89f445ddebdfeaaabcd1-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4dfc89f445ddebdfeaaabcd1',
#        'location': {'address': '10 rd, juhu',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1368,
#         'formattedAddress': ['10 rd, juhu',
#          'Mumbai 400049',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.115077614539207,
#           'lng': 72.83436582858621}],
#         'lat': 19.115077614539207,
#         'lng': 72.83436582858621,
#         'postalCode': '400049',
#         'state': 'Mahārāshtra'},
#        'name': 'Shree Gangour Sweets',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be14758d816c928de9eefd9-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4be14758d816c928de9eefd9',
#        'location': {'address': 'Sher-e-Punjab, Andheri E',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1924,
#         'formattedAddress': ['Sher-e-Punjab, Andheri E',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.123231,
#           'lng': 72.864335}],
#         'lat': 19.123231,
#         'lng': 72.864335,
#         'state': 'Mahārāshtra'},
#        'name': 'Gulati Sweets and Snacks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5149bc6de4b0a74cdad3f0b5-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'primary': True,
#          'shortName': 'Lounge'}],
#        'id': '5149bc6de4b0a74cdad3f0b5',
#        'location': {'address': 'Hotel Imperial Palace 45, Telly Park Road, Mumbai, Maharashtra 400069',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 471,
#         'formattedAddress': ['Hotel Imperial Palace 45, Telly Park Road, Mumbai, Maharashtra 400069',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.118445744847815,
#           'lng': 72.85069835645007}],
#         'lat': 19.118445744847815,
#         'lng': 72.85069835645007,
#         'state': 'Mahārāshtra'},
#        'name': 'Zouk',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '56858521'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587d7f964a520dea322e3-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'primary': True,
#          'shortName': 'Seafood'}],
#        'id': '4b0587d7f964a520dea322e3',
#        'location': {'address': 'Hanuman Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Vile Parle East',
#         'distance': 1865,
#         'formattedAddress': ['Hanuman Road (Vile Parle East)',
#          'Mumbai 400 057',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.10369200713705,
#           'lng': 72.85167550882265}],
#         'lat': 19.10369200713705,
#         'lng': 72.85167550882265,
#         'postalCode': '400 057',
#         'state': 'Mahārāshtra'},
#        'name': 'Gajalee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d7a33c0542ab1f73ea68941-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4d7a33c0542ab1f73ea68941',
#        'location': {'address': 'Parleshwar Rd, Vile Parle East',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Shri Parleshwar Road, Vile Parle East',
#         'distance': 1923,
#         'formattedAddress': ['Parleshwar Rd, Vile Parle East (Shri Parleshwar Road, Vile Parle East)',
#          'Mumbai 400057',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.102417701434753,
#           'lng': 72.84654118690055}],
#         'lat': 19.102417701434753,
#         'lng': 72.84654118690055,
#         'postalCode': '400057',
#         'state': 'Mahārāshtra'},
#        'name': 'Me Marathi',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e109223ae602afe96b554ed-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4e109223ae602afe96b554ed',
#        'location': {'address': 'Opposite Nadco',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Andheri Station, Andheri',
#         'distance': 300,
#         'formattedAddress': ['Opposite Nadco (Andheri Station, Andheri)',
#          'Mumbai 400 058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.119666991815816,
#           'lng': 72.84355993227075}],
#         'lat': 19.119666991815816,
#         'lng': 72.84355993227075,
#         'postalCode': '400 058',
#         'state': 'Mahārāshtra'},
#        'name': 'Cafe Alfa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5814e7cc38fab8bf798ffdfb-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '5814e7cc38fab8bf798ffdfb',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Juhu',
#         'distance': 1317,
#         'formattedAddress': ['Juhu', 'Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.11543877672241,
#           'lng': 72.83472827153204}],
#         'lat': 19.11543877672241,
#         'lng': 72.83472827153204,
#         'state': 'Mahārāshtra'},
#        'name': 'The Bar Stock Exchange (Juhu)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fe875e3e4b03458444080a1-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4fe875e3e4b03458444080a1',
#        'location': {'address': '7-9, Juhu Supreme Shopping Centre, Near Punjab Grill Restaurant, Juhu,',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Gulmohar Road',
#         'distance': 1395,
#         'formattedAddress': ['7-9, Juhu Supreme Shopping Centre, Near Punjab Grill Restaurant, Juhu, (Gulmohar Road)',
#          'Mumbai 400058',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.114797744800704,
#           'lng': 72.83420629709974}],
#         'lat': 19.114797744800704,
#         'lng': 72.83420629709974,
#         'postalCode': '400058',
#         'state': 'Mahārāshtra'},
#        'name': 'BRU World Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fe8ba55e4b010f80f519249-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'primary': True,
#          'shortName': 'Snacks'}],
#        'id': '4fe8ba55e4b010f80f519249',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 1205,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.112690181418145,
#           'lng': 72.83768248684576}],
#         'lat': 19.112690181418145,
#         'lng': 72.83768248684576},
#        'name': 'Mohammad bhurji',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50897650e4b08c1180b99035-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '50897650e4b08c1180b99035',
#        'location': {'address': 'ground/1st floor, Tokyo house,next to andheri sports complex,j.p.road, andheri (west)',
#         'cc': 'IN',
#         'country': 'India',
#         'distance': 1377,
#         'formattedAddress': ['ground/1st floor, Tokyo house,next to andheri sports complex,j.p.road, andheri (west)',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.127250638007126,
#           'lng': 72.83604481603547}],
#         'lat': 19.127250638007126,
#         'lng': 72.83604481603547,
#         'state': 'Mahārāshtra'},
#        'name': 'Road House Bluez',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51eb79b3498e74721c34bcaf-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '51eb79b3498e74721c34bcaf',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1356,
#         'formattedAddress': ['Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.115056269910802,
#           'lng': 72.8344956058685}],
#         'lat': 19.115056269910802,
#         'lng': 72.8344956058685,
#         'state': 'Mahārāshtra'},
#        'name': 'Tiwari Bros. Mithaiwala',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c11fb18a9420f47fea67d51-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4c11fb18a9420f47fea67d51',
#        'location': {'address': 'Cts 215, Opposite Carnival Cinemas, Andheri Kurla Road, Andheri East',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1962,
#         'formattedAddress': ['Cts 215, Opposite Carnival Cinemas, Andheri Kurla Road, Andheri East',
#          'Mumbai 400059',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.114205,
#           'lng': 72.864148}],
#         'lat': 19.114205,
#         'lng': 72.864148,
#         'postalCode': '400059',
#         'state': 'Mahārāshtra'},
#        'name': 'Courtyard Mumbai International Airport',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '69196285'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf9666a8d30d13a4b200218-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4bf9666a8d30d13a4b200218',
#        'location': {'address': 'Chakala Junction, Andheri East',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Andheri East',
#         'distance': 1564,
#         'formattedAddress': ['Chakala Junction, Andheri East (Andheri East)',
#          'Mumbai 400093',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.115372776619047,
#           'lng': 72.8605712200513}],
#         'lat': 19.115372776619047,
#         'lng': 72.8605712200513,
#         'postalCode': '400093',
#         'state': 'Mahārāshtra'},
#        'name': 'Sai Palace Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dd391b0d1643acaa1e3b8a7-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4dd391b0d1643acaa1e3b8a7',
#        'location': {'address': 'Old nagardas road',
#         'cc': 'IN',
#         'city': 'Mumbau',
#         'country': 'India',
#         'crossStreet': 'Nr. Andheri subway',
#         'distance': 652,
#         'formattedAddress': ['Old nagardas road (Nr. Andheri subway)',
#          'Mumbau',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.12375959553322,
#           'lng': 72.85089307715918}],
#         'lat': 19.12375959553322,
#         'lng': 72.85089307715918},
#        'name': 'Sarvodaya Veg. Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e7f3bfa6c253723ab371422-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4e7f3bfa6c253723ab371422',
#        'location': {'address': 'Shop 4A, Arunodaya Society',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Subhash Road',
#         'distance': 1675,
#         'formattedAddress': ['Shop 4A, Arunodaya Society (Subhash Road)',
#          'Mumbai 400057',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.104778659219615,
#           'lng': 72.84852180117035}],
#         'lat': 19.104778659219615,
#         'lng': 72.84852180117035,
#         'postalCode': '400057',
#         'state': 'Mahārāshtra'},
#        'name': 'Shanghai',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52a1f5f0498e44153764be9c-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '52a1f5f0498e44153764be9c',
#        'location': {'address': 'Shop No. 6,\n Ground Floor, Hubtown Solaris,\n N. S. Phadke Marg, Near East West Flyover,\n Andheri East,\n Mumbai - 400069\n Phone',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 699,
#         'formattedAddress': ['Shop No. 6,',
#          ' Ground Floor, Hubtown Solaris,',
#          ' N. S. Phadke Marg, Near East West Flyover,',
#          ' Andheri East,',
#          ' Mumbai - 400069',
#          ' Phone',
#          'Mumbai 400069',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.11449,
#           'lng': 72.85015}],
#         'lat': 19.11449,
#         'lng': 72.85015,
#         'postalCode': '400069',
#         'state': 'Mahārāshtra'},
#        'name': "Domino's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf576d5e5eba59365d12090-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4bf576d5e5eba59365d12090',
#        'location': {'address': 'Sher e Punjab',
#         'cc': 'IN',
#         'country': 'India',
#         'crossStreet': 'Andheri East',
#         'distance': 2002,
#         'formattedAddress': ['Sher e Punjab (Andheri East)',
#          '400076',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.126796504615715,
#           'lng': 72.86391701905842}],
#         'lat': 19.126796504615715,
#         'lng': 72.86391701905842,
#         'postalCode': '400076',
#         'state': 'Mahārāshtra'},
#        'name': 'Natural Ice Cream',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e2b01dcd164223a697cf598-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'primary': True,
# ...
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.13067225353994,
#           'lng': 72.83751881642586}],
#         'lat': 19.13067225353994,
#         'lng': 72.83751881642586,
#         'postalCode': '400053',
#         'state': 'Mahārāshtra'},
#        'name': 'Drunken Munkey',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50517075'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfe2b38d4c01dccaebd10fd-84',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4dfe2b38d4c01dccaebd10fd',
#        'location': {'address': 'Veera Desai Road',
#         'cc': 'IN',
#         'country': 'India',
#         'distance': 1819,
#         'formattedAddress': ['Veera Desai Road', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.131929033909348,
#           'lng': 72.83494834041893}],
#         'lat': 19.131929033909348,
#         'lng': 72.83494834041893},
#        'name': 'Northern Tadka',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c07920f0e0a2d7f2079ed0c-85',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4c07920f0e0a2d7f2079ed0c',
#        'location': {'address': 'Shop Number 9,10, Ground Floor, AWing, Bharat Ark,Azad Nagar,Veera Desai Road,Andh eri(W),Mumbai400053\nPH-02226749191',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1515,
#         'formattedAddress': ['Shop Number 9,10, Ground Floor, AWing, Bharat Ark,Azad Nagar,Veera Desai Road,Andh eri(W),Mumbai400053',
#          'PH-02226749191',
#          'Mumbai 400053',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display', 'lat': 19.13, 'lng': 72.837}],
#         'lat': 19.13,
#         'lng': 72.837,
#         'postalCode': '400053',
#         'state': 'Mahārāshtra'},
#        'name': "Domino's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e01fbae62843b639cfd2648-86',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4e01fbae62843b639cfd2648',
#        'location': {'address': 'Juhu',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1947,
#         'formattedAddress': ['Juhu', 'Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.10223239103693,
#           'lng': 72.84744866136397}],
#         'lat': 19.10223239103693,
#         'lng': 72.84744866136397,
#         'state': 'Mahārāshtra'},
#        'name': 'Cafe Coffee Day',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5129a926e4b0c87c8a53fac8-87',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '5129a926e4b0c87c8a53fac8',
#        'location': {'address': 'Hanuman Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Vile Parle East',
#         'distance': 1782,
#         'formattedAddress': ['Hanuman Road (Vile Parle East)',
#          'Mumbai 400057',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.10460451555764,
#           'lng': 72.85208573162127}],
#         'lat': 19.10460451555764,
#         'lng': 72.85208573162127,
#         'postalCode': '400057',
#         'state': 'Mahārāshtra'},
#        'name': 'Cafe Chokolade',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50f10c93e4b04196705fdea8-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '50f10c93e4b04196705fdea8',
#        'location': {'address': 'Veera Desai Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 1503,
#         'formattedAddress': ['Veera Desai Road',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.13029755015865,
#           'lng': 72.83756814465771}],
#         'lat': 19.13029755015865,
#         'lng': 72.83756814465771,
#         'state': 'Mahārāshtra'},
#        'name': 'Burgs',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-505d5e65e4b0c3135515b592-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/bowling_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e4931735',
#          'name': 'Bowling Alley',
#          'pluralName': 'Bowling Alleys',
#          'primary': True,
#          'shortName': 'Bowling Alley'}],
#        'id': '505d5e65e4b0c3135515b592',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 1549,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.129168240752634,
#           'lng': 72.83562650141774}],
#         'lat': 19.129168240752634,
#         'lng': 72.83562650141774,
#         'neighborhood': 'Jogeshwari West'},
#        'name': 'Andheri sports complex',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53f9d943498eacb60d5af95b-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'primary': True,
#          'shortName': 'Tea Room'}],
#        'id': '53f9d943498eacb60d5af95b',
#        'location': {'address': 'Opp Jain Mandir',
#         'cc': 'IN',
#         'country': 'India',
#         'crossStreet': 'Hanuman Road',
#         'distance': 1826,
#         'formattedAddress': ['Opp Jain Mandir (Hanuman Road)', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.103289265300894,
#           'lng': 72.8466706079974}],
#         'lat': 19.103289265300894,
#         'lng': 72.8466706079974},
#        'name': 'Tea Villa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dd92f7ab0fb8af380b09e73-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '4dd92f7ab0fb8af380b09e73',
#        'location': {'address': 'S. V. Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Jogeshwari (West)',
#         'distance': 1807,
#         'formattedAddress': ['S. V. Road (Jogeshwari (West))',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.135898272834073,
#           'lng': 72.84758136170433}],
#         'lat': 19.135898272834073,
#         'lng': 72.84758136170433,
#         'state': 'Mahārāshtra'},
#        'name': 'Bostan Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5171fb17498ee3a439f76198-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4f4528bc4b90abdf24c9de85',
#          'name': 'Athletics & Sports',
#          'pluralName': 'Athletics & Sports',
#          'primary': True,
#          'shortName': 'Athletics & Sports'}],
#        'id': '5171fb17498ee3a439f76198',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 1572,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.131361465689803,
#           'lng': 72.85485092175313}],
#         'lat': 19.131361465689803,
#         'lng': 72.85485092175313},
#        'name': 'Ismail college. Jogging area',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b7b92c9f964a520a2672fe3-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'primary': True,
#          'shortName': 'Tea Room'}],
#        'id': '4b7b92c9f964a520a2672fe3',
#        'location': {'address': 'Opp. Jain Temple, Vile Parle (E)',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Vile Parle, Hanuman Road',
#         'distance': 1835,
#         'formattedAddress': ['Opp. Jain Temple, Vile Parle (E) (Vile Parle, Hanuman Road)',
#          'Mumbai 400057',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.103211623152532,
#           'lng': 72.84658569525956}],
#         'lat': 19.103211623152532,
#         'lng': 72.84658569525956,
#         'postalCode': '400057',
#         'state': 'Mahārāshtra'},
#        'name': 'Wagh Bakri Tea Lounge',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bcedcd629d4b7130521a9dc-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4bcedcd629d4b7130521a9dc',
#        'location': {'address': 'Hanuman Rd., Vile Parle',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Vile Parle',
#         'distance': 1874,
#         'formattedAddress': ['Hanuman Rd., Vile Parle (Vile Parle)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.10374972904489,
#           'lng': 72.8521324674379}],
#         'lat': 19.10374972904489,
#         'lng': 72.8521324674379,
#         'state': 'Mahārāshtra'},
#        'name': 'Cafe Coffee Day',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59622672b3c9615804212ac2-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '59622672b3c9615804212ac2',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Vile Parle East',
#         'distance': 1771,
#         'formattedAddress': ['Vile Parle East',
#          'Mumbai 400057',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.10474,
#           'lng': 72.852161}],
#         'lat': 19.10474,
#         'lng': 72.852161,
#         'postalCode': '400057',
#         'state': 'Mahārāshtra'},
#        'name': 'Garde Manger Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e5ba8c352b1b78b81b8fbee-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4e5ba8c352b1b78b81b8fbee',
#        'location': {'address': '601, Shree Niketan Hindu Friends, Society Road, Jogeswari(E), Mumbai-400060',
#         'cc': 'IN',
#         'city': 'Jogeswri(E)',
#         'country': 'India',
#         'crossStreet': 'Jogeshwari East',
#         'distance': 1988,
#         'formattedAddress': ['601, Shree Niketan Hindu Friends, Society Road, Jogeswari(E), Mumbai-400060 (Jogeshwari East)',
#          'Jogeswri(E) 400057',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.13739932639962,
#           'lng': 72.84898913476594}],
#         'lat': 19.13739932639962,
#         'lng': 72.84898913476594,
#         'postalCode': '400057',
#         'state': 'Mahārāshtra'},
#        'name': 'Amul Scooping Parlour',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Andheri West, Mumbai',
#   'headerLocation': 'Andheri West',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 19.13769761800002,
#     'lng': 72.86543586669762},
#    'sw': {'lat': 19.101697581999986, 'lng': 72.82740513330236}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 97}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                            name            categories        lat        lng
# 0             Merwans Cake shop                Bakery  19.119300  72.845418
# 1              Narayan Sandwich        Sandwich Place  19.121398  72.850270
# 2  Radha Krishna Veg Restaurant     Indian Restaurant  19.115130  72.843060
# 3                    McDonald's  Fast Food Restaurant  19.119691  72.846102
# 4              Shawarma Factory    Falafel Restaurant  19.124591  72.840398

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 97 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here

M5J_venues = getNearbyVenues(names=df_mum['Neighbourhood'],
                                   latitudes=df_mum['Latitude'],
                                   longitudes=df_mum['Longitude']
                                  )
# Out:
# Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Nagar,Lokhandwala,Marol,Model Town,Oshiwara,Poonam Nagar,Sahar,Saki Naka,Seven Bungalows,Versova
# Bandra Kurla Complex,Bandstand Promenade,Gandhi Nagar,Kherwadi,Lands End,Pali Hill,Bandra Reclamation
# I.C. Colony,L.I.C. Colony aka Jeevan Bhima Nagar,Eksar Colony,Shimpoli,Gorai,Kora Kendra,Vazira Naka,Babhai,Chikuwadi,Yogi Nagar
# Magathane,Nancy Colony,Sukurwadi
# Dahisar
# Aarey Milk Colony,Motilal Nagar,Bangur Nagar,Gokuldham,Pandurangwadi,NESCO colony
# Jogeshwari West,Jogeshwari East
# Juhu
# Charkop,Poisar,Hindustan Naka,Mahavir Nagar
# Samta nagar,Damu nagar,Thakur complex,Thakur village,Lokandwala township,Akurli road,Janupada,Hanuman nagar
# Pali Naka,Khar Danda
# Dindoshi,Sunder Nagar,Pathanwadi,Rani Sati Marg,Malvani
# Kalina
# Naigaon,Nalasopara
# Virar
# Irla
# Antop Hill
# Altamount Road
# Bhuleshwar
# Breach Candy
# Carmichael Road
# Cavel
# Churchgate
# Cotton Green
# Cuffe Parade
# Cumbala Hill
# Currey Road
# Dhobitalao
# Dongri
# Kala Ghoda
# Kemps Corner
# Lalbaug
# Lower Parel
# Mahalaxmi
# Mahim
# Malabar Hill
# Marine Drive, Mumbai
# Marine Lines
# Mumbai Central
# Nariman Point
# Prabhadevi
# Sion
# Walkeshwar
# Worli
# C.G.S. colony
# Dagdi Chawl,Ghodapdeo
# Navy Nagar
# Hindu colony,Parsi Colony
# Ballard Estate
# Khotachiwadi
# Chira Bazaar,Fanas Wadi
# Chor Bazaar
# Matunga[edit]
# Lalbaug
# Gowalia Tank

# %%
print(M5J_venues.shape)
M5J_venues.head(20)
# Out:
# (950, 7)
#                                          Neighborhood  ...        Venue Category
# 0   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...                Bakery
# 1   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...  Fast Food Restaurant
# 2   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...        Sandwich Place
# 3   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...     Indian Restaurant
# 4   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...                Lounge
# 5   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...  Fast Food Restaurant
# 6   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...     Indian Restaurant
# 7   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...            Restaurant
# 8   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...            Food Court
# 9   Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...          Burger Joint
# 10  Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Na...  ...     Indian Restaurant
# 11  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...                  Café
# 12  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...     Indian Restaurant
# 13  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...     Indian Restaurant
# 14  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...         Train Station
# 15  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...     Convenience Store
# 16  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...     Indian Restaurant
# 17  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...                  Café
# 18  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...               Brewery
# 19  Bandra Kurla Complex,Bandstand Promenade,Gandh...  ...    Italian Restaurant
#
# [20 rows x 7 columns]

# %%
M5J_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Aarey Milk Colony,Motilal Nagar,Bangur Nagar,Go...                     16  ...              16
# Altamount Road                                                         18  ...              18
# Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Nag...                     11  ...              11
# Antop Hill                                                              5  ...               5
# Ballard Estate                                                         48  ...              48
# Bandra Kurla Complex,Bandstand Promenade,Gandhi...                     15  ...              15
# Bhuleshwar                                                             13  ...              13
# Breach Candy                                                           21  ...              21
# C.G.S. colony                                                           5  ...               5
# Carmichael Road                                                        30  ...              30
# Cavel                                                                   9  ...               9
# Charkop,Poisar,Hindustan Naka,Mahavir Nagar                            10  ...              10
# Chira Bazaar,Fanas Wadi                                                 9  ...               9
# Chor Bazaar                                                            12  ...              12
# Churchgate                                                             50  ...              50
# Cotton Green                                                            4  ...               4
# Cuffe Parade                                                           21  ...              21
# Cumbala Hill                                                           23  ...              23
# Currey Road                                                             4  ...               4
# Dagdi Chawl,Ghodapdeo                                                  13  ...              13
# Dahisar                                                                 9  ...               9
# Dhobitalao                                                             24  ...              24
# Dindoshi,Sunder Nagar,Pathanwadi,Rani Sati Marg...                      7  ...               7
# Dongri                                                                  5  ...               5
# Gowalia Tank                                                           11  ...              11
# Hindu colony,Parsi Colony                                              27  ...              27
# I.C. Colony,L.I.C. Colony aka Jeevan Bhima Naga...                     12  ...              12
# Irla                                                                   24  ...              24
# Jogeshwari West,Jogeshwari East                                         5  ...               5
# Juhu                                                                   56  ...              56
# Kala Ghoda                                                             42  ...              42
# Kalina                                                                 21  ...              21
# Kemps Corner                                                           32  ...              32
# Khotachiwadi                                                           34  ...              34
# Lalbaug                                                                10  ...              10
# Lower Parel                                                            48  ...              48
# Magathane,Nancy Colony,Sukurwadi                                        3  ...               3
# Mahalaxmi                                                               8  ...               8
# Mahim                                                                   9  ...               9
# Malabar Hill                                                            6  ...               6
# Marine Drive, Mumbai                                                    7  ...               7
# Marine Lines                                                           11  ...              11
# Matunga[edit]                                                          30  ...              30
# Mumbai Central                                                         13  ...              13
# Naigaon,Nalasopara                                                      2  ...               2
# Nariman Point                                                          34  ...              34
# Navy Nagar                                                             15  ...              15
# Pali Naka,Khar Danda                                                   24  ...              24
# Prabhadevi                                                             19  ...              19
# Samta nagar,Damu nagar,Thakur complex,Thakur vi...                     21  ...              21
# Sion                                                                   21  ...              21
# Virar                                                                   2  ...               2
# Walkeshwar                                                             14  ...              14
# Worli                                                                   7  ...               7
#
# [54 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(M5J_venues['Venue Category'].unique())))
# Out:
# There are 151 uniques categories.

# %%
map_restaurants = folium.Map(location=[latitude, longitude], zoom_start=11, tiles="openstreetmap", 
                            attr="<a href=https://github.com/python-visualization/folium/>Folium</a>")


# set color scheme for the Venues based on the Major Districts
Districts = ['Nariman Point', 'Malabar Hill', 'Breach Candy', 'Juhu', 'Hindu colony,Parsi Colony','Churchgate','Dahisar','Lower Parel','Sion','Ballard Estate']
df_5 = M5J_venues[M5J_venues['Neighborhood'].isin(Districts)]
print(df_5.shape)
x = np.arange(len(Districts))

rainbow = ['#00ff00', '#ff00ff','#0000ff','#ffa500' ,'#ff0000','#a9a9a9','#f032e6','#911eb4','#bfef45','#f58231']

# add markers to the map
# markers_colors = []
for lat, lon, poi, distr,label in zip(df_5['Venue Latitude'], 
                                  df_5['Venue Longitude'], 
                                  df_5['Venue Category'], 
                                  df_5['Neighborhood'],
                                  df_5['Venue']):
    label = folium.Popup(str(poi) + ' ' + str(label), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=7,
        popup=label,
        color=rainbow[Districts.index(distr)-1],
        fill=True,
        fill_color=rainbow[Districts.index(distr)-1],
        fill_opacity=0.3).add_to(map_restaurants)
       
map_restaurants
# Out:
# (320, 7)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print (M5J_venues['Venue Category'].value_counts())
# Out:
# Indian Restaurant                  121
# Café                                54
# Fast Food Restaurant                42
# Chinese Restaurant                  31
# Coffee Shop                         30
# Pizza Place                         27
# Bakery                              26
# Restaurant                          25
# Bar                                 23
# Sandwich Place                      22
# Lounge                              20
# Dessert Shop                        20
# Italian Restaurant                  20
# Hotel                               19
# Snack Place                         17
# Ice Cream Shop                      17
# Department Store                    16
# Gym                                 15
# Train Station                       13
# Asian Restaurant                    12
# Seafood Restaurant                  11
# Theater                             10
# Movie Theater                       10
# Breakfast Spot                      10
# Juice Bar                           10
# Gym / Fitness Center                10
# Bookstore                            9
# Spa                                  9
# Vegetarian / Vegan Restaurant        9
# Market                               9
#                                   ...
# Hookah Bar                           1
# Soccer Field                         1
# Moving Target                        1
# Miscellaneous Shop                   1
# Steakhouse                           1
# Sports Bar                           1
# Automotive Shop                      1
# Hockey Arena                         1
# German Restaurant                    1
# Opera House                          1
# Comfort Food Restaurant              1
# Thai Restaurant                      1
# American Restaurant                  1
# Trail                                1
# Auto Garage                          1
# Wine Bar                             1
# Molecular Gastronomy Restaurant      1
# Hotel Bar                            1
# Monument / Landmark                  1
# Office                               1
# Zoo                                  1
# Afghan Restaurant                    1
# Tourist Information Center           1
# Paper / Office Supplies Store        1
# Bistro                               1
# Business Service                     1
# New American Restaurant              1
# Bus Stop                             1
# North Indian Restaurant              1
# Noodle House                         1
# Name: Venue Category, Length: 151, dtype: int64

# %%
# create a dataframe of top 10 categories
M5J_venues_Top10 = M5J_venues['Venue Category'].value_counts()[0:10].to_frame(name='frequency')
M5J_venues_Top10=M5J_venues_Top10.reset_index()
#Tokyo_5_Dist_Venues_Top10

M5J_venues_Top10.rename(index=str, columns={"index": "Venue Category", "frequency": "Frequency"}, inplace=True)
M5J_venues_Top10
# Out:
#          Venue Category  Frequency
# 0     Indian Restaurant        121
# 1                  Café         54
# 2  Fast Food Restaurant         42
# 3    Chinese Restaurant         31
# 4           Coffee Shop         30
# 5           Pizza Place         27
# 6                Bakery         26
# 7            Restaurant         25
# 8                   Bar         23
# 9        Sandwich Place         22

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18,7))
s=sns.barplot(x="Venue Category", y="Frequency", data=M5J_venues_Top10)
s.set_xticklabels(s.get_xticklabels(), rotation=30)
plt.title('10 Most Frequently Occuring Venues in 5 Major Places of Mumbai', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues.png", dpi=300)
plt.show()

# %% [markdown]
# **chinese Restaurant is one of the Most Frequent Venues in 5 Major Districts of Mumbai.**

# %% [markdown]
# ### Analyze Each Neighborhood

# %%
# one hot encoding
M5J_onehot = pd.get_dummies(df_5[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
M5J_onehot['Neighborhood'] = df_5['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [M5J_onehot.columns[-1]] + list(M5J_onehot.columns[:-1])
M5J_onehot = M5J_onehot[fixed_columns]

#M5J_onehot.head()

# %%
M5J_onehot.shape
# Out:
# (320, 99)

# %%
M5J_grouped = M5J_onehot.groupby('Neighborhood').mean().reset_index()
#M5J_grouped

# %%
M5J_grouped.shape
# Out:
# (10, 99)

# %%
num_top_venues = 5

for hood in M5J_grouped['Neighborhood']:
    #print("----"+hood+"----")
    temp = M5J_grouped[M5J_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    #print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    #print('\n')

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = M5J_grouped['Neighborhood']

for ind in np.arange(M5J_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(M5J_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                 Neighborhood  ... 10th Most Common Venue
# 0             Ballard Estate  ...       Parsi Restaurant
# 1               Breach Candy  ...                 Lounge
# 2                 Churchgate  ...                    Bar
# 3                    Dahisar  ...            Yoga Studio
# 4  Hindu colony,Parsi Colony  ...                  Plaza
#
# [5 rows x 11 columns]

# %%
# Let's try Categorical plot 
fig = plt.figure(figsize=(25,15))

sns.set(font_scale=1.1)
ax = plt.subplot(3,3,1)
sns.violinplot(x="Neighborhood", y="Indian Restaurant", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.xlabel("")
ax = plt.subplot(3,3,2)
sns.violinplot(x="Neighborhood", y="Bar", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.xlabel("")
plt.subplot(3,3,3)
sns.violinplot(x="Neighborhood", y="Café", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.subplot(3,3,4)
sns.violinplot(x="Neighborhood", y="Sandwich Place", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.subplot(3,3,5)
sns.violinplot(x="Neighborhood", y="Fast Food Restaurant", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.subplot(3,3,6)
sns.violinplot(x="Neighborhood", y="Chinese Restaurant", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.subplot(3,3,7)
sns.violinplot(x="Neighborhood", y="Coffee Shop", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.subplot(3,3,8)
sns.violinplot(x="Neighborhood", y="Dessert Shop", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
plt.subplot(3,3,9)
sns.violinplot(x="Neighborhood", y="Bakery", data=M5J_onehot, cut=0);
plt.xticks(rotation=45)
#ax.title.set_text("5 Major Districts and Violin Plots of Most Frequently Visited Restaurants")
ax.text(-4.0, 1.1, '5 Major Districts and Violin Plots of Most Frequently Visited Restaurants', fontsize=14)
plt.savefig ("Violin_plots_Dist_Frequent_Restaurant.png", dpi=240)
plt.show()

# %% [markdown]
# ## 3. Cluster Neighborhoods

# %%
from sklearn.cluster import KMeans
# set number of clusters
kclusters = 4

M5J_grouped_clustering = M5J_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(M5J_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 1, 1, 0, 2, 1, 1, 3, 1, 2], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

M5J_merged = df_mum

# %%
# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
M5J_merged = M5J_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

M5J_merged.head(100) # check the last columns!
# Out:
#                Town  ... 10th Most Common Venue
# 0   Western Suburbs  ...                    NaN
# 1   Western Suburbs  ...                    NaN
# 2   Western Suburbs  ...                    NaN
# 3   Western Suburbs  ...                    NaN
# 4   Western Suburbs  ...            Yoga Studio
# 5   Western Suburbs  ...                    NaN
# 6   Western Suburbs  ...                    NaN
# 7   Western Suburbs  ...      Indian Restaurant
# 8   Western Suburbs  ...                    NaN
# 9   Western Suburbs  ...                    NaN
# 10  Western Suburbs  ...                    NaN
# 11  Western Suburbs  ...                    NaN
# 12  Western Suburbs  ...                    NaN
# 13  Western Suburbs  ...                    NaN
# 14  Western Suburbs  ...                    NaN
# 15  Western Suburbs  ...                    NaN
# 16     South Mumbai  ...                    NaN
# 17     South Mumbai  ...                    NaN
# 18     South Mumbai  ...                    NaN
# 19     South Mumbai  ...                 Lounge
# 20     South Mumbai  ...                    NaN
# 21     South Mumbai  ...                    NaN
# 22     South Mumbai  ...                    Bar
# 23     South Mumbai  ...                    NaN
# 24     South Mumbai  ...                    NaN
# 25     South Mumbai  ...                    NaN
# 26     South Mumbai  ...                    NaN
# 27     South Mumbai  ...                    NaN
# 28     South Mumbai  ...                    NaN
# 29     South Mumbai  ...                    NaN
# 30     South Mumbai  ...                    NaN
# 31     South Mumbai  ...                    NaN
# 32     South Mumbai  ...               Tea Room
# 33     South Mumbai  ...                    NaN
# 34     South Mumbai  ...                    NaN
# 35     South Mumbai  ...         Cricket Ground
# 36     South Mumbai  ...                    NaN
# 37     South Mumbai  ...                    NaN
# 38     South Mumbai  ...                    NaN
# 39     South Mumbai  ...     Chinese Restaurant
# 40     South Mumbai  ...                    NaN
# 41     South Mumbai  ...               Bus Stop
# 42     South Mumbai  ...                    NaN
# 43     South Mumbai  ...                    NaN
# 44     South Mumbai  ...                    NaN
# 45     South Mumbai  ...                    NaN
# 46     South Mumbai  ...                    NaN
# 47     South Mumbai  ...                  Plaza
# 48     South Mumbai  ...       Parsi Restaurant
# 49     South Mumbai  ...                    NaN
# 50     South Mumbai  ...                    NaN
# 51     South Mumbai  ...                    NaN
# 52     South Mumbai  ...                    NaN
# 53     South Mumbai  ...                    NaN
# 54     South Mumbai  ...                    NaN
#
# [55 rows x 16 columns]

# %%
M5J_merged= M5J_merged.dropna()
M5J_merged['Cluster Labels'] = M5J_merged['Cluster Labels'].apply(lambda x:int(x))
M5J_merged.head()
# Out:
#                Town  ... 10th Most Common Venue
# 4   Western Suburbs  ...            Yoga Studio
# 7   Western Suburbs  ...      Indian Restaurant
# 19     South Mumbai  ...                 Lounge
# 22     South Mumbai  ...                    Bar
# 32     South Mumbai  ...               Tea Room
#
# [5 rows x 16 columns]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(M5J_merged['Latitude'], M5J_merged['Longitude'], M5J_merged['Neighbourhood'], M5J_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    print(cluster)
    folium.CircleMarker(
        [np.float(lat), np.float(lon)],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# 0
# 1
# 1
# 1
# 1
# 3
# 1
# 2
# 2
# 2
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map
map_restaurants10 = folium.Map(location=[latitude, longitude], tiles='cartodbpositron', 
                               attr="<a href=https://github.com/python-visualization/folium/>Folium</a>")

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
#rainbow = ['#00ff00', '#ff00ff','#0000ff','#ffa500' ,'#ff0000']
#Districts = ['Nagatacho', 'Nihonbashi', 'Shinjuku', 'Shinagawa', 'Shibuya']
Districts = ['Nariman Point', 'Malabar Hill', 'Breach Candy', 'Juhu', 'Hindu colony,Parsi Colony','Churchgate','Dahisar','Lower Parel','Sion','Ballard Estate']
df_5 = M5J_merged[M5J_merged['Neighbourhood'].isin(Districts)]
list_rest_no = [34, 7, 20, 52, 28,50,9,48,21,48]
# add markers to the map
for lat, lon, poi, cluster in zip(df_5['Latitude'], 
                                  df_5['Longitude'], 
                                  df_5['Neighbourhood'], 
                                  df_5['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=list_rest_no[Districts.index(poi)]*0.5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_restaurants10)
       
map_restaurants10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
M5J_merged.loc[M5J_merged['Cluster Labels'] == 0, M5J_merged.columns[[1] + list(range(5, M5J_merged.shape[1]))]]
# Out:
#    Station  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 4  Dahisar               0  ...  Fast Food Restaurant            Yoga Studio
#
# [1 rows x 12 columns]

# %%
M5J_merged.loc[M5J_merged['Cluster Labels'] == 1, M5J_merged.columns[[1] + list(range(5, M5J_merged.shape[1]))]]
# Out:
#           Station  ...  10th Most Common Venue
# 7            Juhu  ...       Indian Restaurant
# 19   Breach Candy  ...                  Lounge
# 22     Churchgate  ...                     Bar
# 32    Lower Parel  ...                Tea Room
# 39  Nariman Point  ...      Chinese Restaurant
#
# [5 rows x 12 columns]

# %%
M5J_merged.loc[M5J_merged['Cluster Labels'] == 2, M5J_merged.columns[[1] + list(range(5, M5J_merged.shape[1]))]]
# Out:
#    Station  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 41    Sion               2  ...      Business Service               Bus Stop
# 47   Dadar               2  ...                Lounge                  Plaza
# 48    Fort               2  ...           Pizza Place       Parsi Restaurant
#
# [3 rows x 12 columns]

# %%
M5J_merged.loc[M5J_merged['Cluster Labels'] == 3, M5J_merged.columns[[1] + list(range(5, M5J_merged.shape[1]))]]
# Out:
#          Station  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 35  Malabar Hill               3  ...        Cosmetics Shop         Cricket Ground
#
# [1 rows x 12 columns]

# %% [markdown]
# ## 4. Collect Chinese Restaurant info for each Neighborhood for prospective buisiness Location
#
# https://github.com/kunal-chhabra/Coursera_Capstone/blob/master/The%20Battle%20of%20Neighborhoods.ipynb

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=2000
    LIMIT=100
    CLIENT_ID = 'QSOKNRAASIUJLTFPCEXHCZD0K11LEPJ1NL05S4FG33XPLWBW' # your Foursquare ID
    CLIENT_SECRET = 'T550UGX5ZEOHGNRS3BV5D3BCJ4JFPTW40XBWREO12PDYM5GU' # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
#Neighborhood	Neighborhood Latitude	Neighborhood Longitude	Venue	Venue Latitude	Venue Longitude	Venue Category
# prepare neighborhood list that contains chinese resturants
column_names=['Station', 'Neighborhood', 'ID','Name']
chinese_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in df_mum.values.tolist():
    Town,Station,Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    Chinese_resturants=venues[venues['Category']=='Chinese Restaurant']  
    print('(',count,'/',len(df_mum),')','Chinese Restaurants in '+Neighborhood+', '+Station+':'+str(len(Chinese_resturants)))
    for resturant_detail in Chinese_resturants.values.tolist():
        id, name , category=resturant_detail
        chinese_rest_ny = chinese_rest_ny.append({'Station': Station,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 55 ) Chinese Restaurants in Amboli,Chakala,D.N. Nagar,Four Bungalows,JB Nagar,Lokhandwala,Marol,Model Town,Oshiwara,Poonam Nagar,Sahar,Saki Naka,Seven Bungalows,Versova, Andheri:4
# ( 2 / 55 ) Chinese Restaurants in Bandra Kurla Complex,Bandstand Promenade,Gandhi Nagar,Kherwadi,Lands End,Pali Hill,Bandra Reclamation, Bandra:2
# ( 3 / 55 ) Chinese Restaurants in I.C. Colony,L.I.C. Colony aka Jeevan Bhima Nagar,Eksar Colony,Shimpoli,Gorai,Kora Kendra,Vazira Naka,Babhai,Chikuwadi,Yogi Nagar, Borivali:5
# ( 4 / 55 ) Chinese Restaurants in Magathane,Nancy Colony,Sukurwadi, Borivali East:4
# ( 5 / 55 ) Chinese Restaurants in Dahisar, Dahisar:3
# ( 6 / 55 ) Chinese Restaurants in Aarey Milk Colony,Motilal Nagar,Bangur Nagar,Gokuldham,Pandurangwadi,NESCO colony, Goregaon:2
# ( 7 / 55 ) Chinese Restaurants in Jogeshwari West,Jogeshwari East, Jogeshwari:4
# ( 8 / 55 ) Chinese Restaurants in Juhu, Juhu:3
# ( 9 / 55 ) Chinese Restaurants in Charkop,Poisar,Hindustan Naka,Mahavir Nagar, Kandivali west:4
# ( 10 / 55 ) Chinese Restaurants in Samta nagar,Damu nagar,Thakur complex,Thakur village,Lokandwala township,Akurli road,Janupada,Hanuman nagar, Kandivali east:2
# ( 11 / 55 ) Chinese Restaurants in Pali Naka,Khar Danda, Khar:2
# ( 12 / 55 ) Chinese Restaurants in Dindoshi,Sunder Nagar,Pathanwadi,Rani Sati Marg,Malvani, Malad:3
# ( 13 / 55 ) Chinese Restaurants in Kalina, Santacruz:2
# ( 14 / 55 ) Chinese Restaurants in Naigaon,Nalasopara, Vasai:0
# ( 15 / 55 ) Chinese Restaurants in Virar, Virar:0
# ( 16 / 55 ) Chinese Restaurants in Irla, Vile Parle:3
# ( 17 / 55 ) Chinese Restaurants in Antop Hill, Agripada:3
# ( 18 / 55 ) Chinese Restaurants in Altamount Road, Altamount Road:3
# ( 19 / 55 ) Chinese Restaurants in Bhuleshwar, Bhuleshwar:2
# ( 20 / 55 ) Chinese Restaurants in Breach Candy, Breach Candy:2
# ( 21 / 55 ) Chinese Restaurants in Carmichael Road, Carmichael Road:4
# ( 22 / 55 ) Chinese Restaurants in Cavel, Cavel:3
# ( 23 / 55 ) Chinese Restaurants in Churchgate, Churchgate:3
# ( 24 / 55 ) Chinese Restaurants in Cotton Green, Cotton Green:0
# ( 25 / 55 ) Chinese Restaurants in Cuffe Parade, Cuffe Parade:3
# ( 26 / 55 ) Chinese Restaurants in Cumbala Hill, Cumballa Hill:2
# ( 27 / 55 ) Chinese Restaurants in Currey Road, Currey Road:2
# ( 28 / 55 ) Chinese Restaurants in Dhobitalao, Dhobitalao:2
# ( 29 / 55 ) Chinese Restaurants in Dongri, Dongri:1
# ( 30 / 55 ) Chinese Restaurants in Kala Ghoda, Kala Ghoda:3
# ( 31 / 55 ) Chinese Restaurants in Kemps Corner, Kemps Corner:3
# ( 32 / 55 ) Chinese Restaurants in Lalbaug, Lalbaug:2
# ( 33 / 55 ) Chinese Restaurants in Lower Parel, Lower Parel:1
# ( 34 / 55 ) Chinese Restaurants in Mahalaxmi, Mahalaxmi:4
# ( 35 / 55 ) Chinese Restaurants in Mahim, Mahim:7
# ( 36 / 55 ) Chinese Restaurants in Malabar Hill, Malabar Hill:3
# ( 37 / 55 ) Chinese Restaurants in Marine Drive, Mumbai, Marine Drive:2
# ( 38 / 55 ) Chinese Restaurants in Marine Lines, Marine Lines:2
# ( 39 / 55 ) Chinese Restaurants in Mumbai Central, Mumbai Central:2
# ( 40 / 55 ) Chinese Restaurants in Nariman Point, Nariman Point:3
# ( 41 / 55 ) Chinese Restaurants in Prabhadevi, Prabhadevi:5
# ( 42 / 55 ) Chinese Restaurants in Sion, Sion:2
# ( 43 / 55 ) Chinese Restaurants in Walkeshwar, Walkeshwar:3
# ( 44 / 55 ) Chinese Restaurants in Worli, Worli:2
# ( 45 / 55 ) Chinese Restaurants in C.G.S. colony, Antop Hill:1
# ( 46 / 55 ) Chinese Restaurants in Dagdi Chawl,Ghodapdeo, Byculla:3
# ( 47 / 55 ) Chinese Restaurants in Navy Nagar, Colaba:4
# ( 48 / 55 ) Chinese Restaurants in Hindu colony,Parsi Colony, Dadar:6
# ( 49 / 55 ) Chinese Restaurants in Ballard Estate, Fort:2
# ( 50 / 55 ) Chinese Restaurants in Khotachiwadi, Girgaon:1
# ( 51 / 55 ) Chinese Restaurants in Chira Bazaar,Fanas Wadi, Kalbadevi:3
# ( 52 / 55 ) Chinese Restaurants in Chor Bazaar, Kamathipura:3
# ( 53 / 55 ) Chinese Restaurants in Matunga[edit], Matunga:5
# ( 54 / 55 ) Chinese Restaurants in Lalbaug, Lalbaug:2
# ( 55 / 55 ) Chinese Restaurants in Gowalia Tank, Tardeo:2

# %%
chinese_rest_ny.head()
# Out:
#    Station  ...              Name
# 0  Andheri  ...       King chilly
# 1  Andheri  ...          Shanghai
# 2  Andheri  ...   Shetty's Corner
# 3  Andheri  ...  5 Spice , Bandra
# 4   Bandra  ...       Wok Express
#
# [5 rows x 4 columns]

# %%
chinese_rest_ny.shape
# Out:
# (149, 4)

# %% [markdown]
# We got 153 Chinese Resturants across Mumbai City

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Chinese ian Resturants for each Station in Mumbai City')
#On x-axis
plt.xlabel('Station', fontsize = 15)
#On y-axis
plt.ylabel('No.of chinese Resturants', fontsize=15)
#giving a bar plot
chinese_rest_ny.groupby('Station')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# So Mahim in Mahim has the highest number of chinese Resturants with a total count of 7.

# %%
chinese_rest_ny[chinese_rest_ny['Neighborhood']=='Mahim']
# Out:
#    Station Neighborhood                        ID                      Name
# 86   Mahim        Mahim  4da0746858c2224bea9f5279                 Icy Spicy
# 87   Mahim        Mahim  4b0587d7f964a520dfa322e3  Status Restaurants & Bar
# 88   Mahim        Mahim  4d346742eefa8cfa2e624ab3            Paul's Chinese
# 89   Mahim        Mahim  4cd6628b76ab721e9deb726a          Jim-me's Kitchen
# 90   Mahim        Mahim  4b0587daf964a52055a422e3  Gypsy Chinese Restaurant
# 91   Mahim        Mahim  52d25c5b11d257eb1de0832c              China Bistro
# 92   Mahim        Mahim  4e4d4d63aeb77d4a40e6c5db              Lucky Dragon

# %% [markdown]
# ## 5. Ranking of each resturant for competition check
#
# https://github.com/kunal-chhabra/Coursera_Capstone/blob/master/The%20Battle%20of%20Neighborhoods.ipynb

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = 'QSOKNRAASIUJLTFPCEXHCZD0K11LEPJ1NL05S4FG33XPLWBW' # your Foursquare ID
    CLIENT_SECRET = 'T550UGX5ZEOHGNRS3BV5D3BCJ4JFPTW40XBWREO12PDYM5GU' # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    print(venue_id,results)
    #if('venue' in results['response'].keys()):
    if(True):
      venue_data=results['response']['venue']
      venue_details=[]
      try:
          venue_id=venue_data['id']
          venue_name=venue_data['name']
          venue_likes=venue_data['likes']['count']
          venue_rating=venue_data['rating']
          venue_tips=venue_data['tips']['count']
          venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
      except KeyError:
          pass
        
      column_names=['ID','Name','Likes','Rating','Tips']
      df = pd.DataFrame(venue_details,columns=column_names)
      return df
    #else:
      #venue_details=[]
      #column_names=['ID','Name','Likes','Rating','Tips']
      #df = pd.DataFrame(venue_details,columns=column_names)
      #return df

# %%
# prepare neighborhood list that contains chinese resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
chinese_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in chinese_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(chinese_rest_ny),')','processed')
    chinese_rest_stats_ny = chinese_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
# 51fb7853498e2d2b68bc9b7c {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5d6cb7ae018cbb002ce0943a'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-00f98b66de2b> in <module>()
#       7     Borough,Neighborhood,ID,Name=row
#       8     try:
# ----> 9         venue_details=get_venue_details(ID)
#      10         print(venue_details)
#      11         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-52-4661366ea1e4> in get_venue_details(venue_id)
#      17     #if('venue' in results['response'].keys()):
#      18     if(True):
# ---> 19       venue_data=results['response']['venue']
#      20       venue_details=[]
#      21       try:
#
# KeyError: 'venue'

# %%
chinese_rest_stats_ny.shape

# %%
chinese_rest_ny.shape

# %%
chinese_rest_stats_ny.to_csv('chinese_rest_stats_ny.csv', index=False)

# %%
indian_rest_stats_ny_csv.head()

# %%
indian_rest_stats_ny.info()

# %%
indian_rest_stats_ny['Likes']=indian_rest_stats_ny['Likes'].astype('float64')

# %%
indian_rest_stats_ny['Tips']=indian_rest_stats_ny['Tips'].astype('float64')

# %%
indian_rest_stats_ny.info()

# %%
# Resturant with maximum Likes
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Likes'].idxmax()]

# %%
# Resturant with maximum Rating
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Rating'].idxmax()]

# %%
# Resturant with maximum Tips
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Tips'].idxmax()]

# %%
ny_neighborhood_stats=indian_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']

# %%
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)

# %%
ny_borough_stats=indian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']

# %%
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average rating of Indian Resturants for each Borough')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Rating', fontsize=15)
#giving a bar plot
indian_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=9.0]
ny_neighborhood_stats

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,new_york_data, on='Neighborhood')

# %%
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats

# %%
# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'

# %%
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)

# %% [markdown]
# Now that we have visualized the Neighborhoods.
# Lets Visualize Boroughs based on average Rating

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
ny_geo = r'Borough Boundaries.geojson'

ny_map.choropleth(
    geo_data=ny_geo,
    data=ny_borough_stats,
    columns=['Borough', 'Average Rating'],
    key_on='feature.properties.boro_name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Average Rating'
)

# display map
# as this is huge map data , we will save it to a file
ny_map.save('borough_rating.html')

# %% [markdown]
# **Conclusion**
#
# Astoria(Queens), Blissville(Queens), Civic Center(Manhattan) are some of the best neighborhoods for indian cuisine.
#
# Manhattan have potential Indian Resturant Market
#
# Staten Island ranks last in average rating of Indian Resturants.
#
# Manhattan is the best place to stay if you prefer Indian Cuisine.
#
#
# **Limitations**
#
# The ranking is purely on basis of rating of resturants
#
# The accuracy of data depends purely depends on the data provided by FourSquare
